# %%
import pandas as pd

# %%
df = pd.read_fwf("./New_Dataset/31.txt")

# %%
df.shape
# Out:
# (9999, 28)

# %%
df.head()
# Out:
#    2018  126  02  37  57  261  04  -0.04690  -0.03850  0.00582  ...  51.00.1  \
# 0  2018  126   2  38   2  381  14   -0.0469   -0.0385  0.00582  ...     51.0
# 1  2018  126   2  38   3  917  17   -0.0469   -0.0385  0.00582  ...     51.0
# 2  2018  126   2  38   5  453  20   -0.0469   -0.0385  0.00582  ...     51.0
# 3  2018  126   2  38   6  477  22   -0.0469   -0.0385  0.00582  ...     51.0
# 4  2018  126   2  38   6  989  23   -0.0469   -0.0385  0.00582  ...     51.0
#
#    SYNC  ON  ON.1  ON.2  SYNC.1  NOT_USBL  ENA  LOW ON.3
# 0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 1  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 2  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 3  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 4  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
#
# [5 rows x 28 columns]

# %% [markdown]
# # Delete non numerical columns

# %%
df.drop(df.iloc[:,14:28], inplace=True,axis=1)
df
# Out:
#       2018  126  02  37  57  261  04  -0.04690  -0.03850  0.00582  0.01131  \
# 0     2018  126   2  38   2  381  14   -0.0469   -0.0385  0.00582  0.01131
# 1     2018  126   2  38   3  917  17   -0.0469   -0.0385  0.00582  0.01131
# 2     2018  126   2  38   5  453  20   -0.0469   -0.0385  0.00582  0.01131
# 3     2018  126   2  38   6  477  22   -0.0469   -0.0385  0.00582  0.01131
# 4     2018  126   2  38   6  989  23   -0.0469   -0.0385  0.00582  0.01131
# ...    ...  ...  ..  ..  ..  ...  ..       ...       ...      ...      ...
# 9994  2018  128   1  54  28  631  23   -0.0469   -0.0385  0.00577  0.01131
# 9995  2018  128   1  54  30  167  26   -0.0469   -0.0385  0.00577  0.01131
# 9996  2018  128   1  54  31  703  29   -0.0469   -0.0385  0.00577  0.01131
# 9997  2018  128   1  54  35  287   4   -0.0469   -0.0385  0.00577  0.01131
# 9998  2018  128   1  54  40  407  14   -0.0469   -0.0385  0.00577  0.01131
#
#       -0.09810  -0.06870  0.00661
# ...

# %%
df.columns = ['date','col1','col2','col3','col4','col5','col6','col7','col8','col9','col10','col11','col12','col13']
df
# Out:
#       date  col1  col2  col3  col4  col5  col6    col7    col8     col9  \
# 0     2018   126     2    38     2   381    14 -0.0469 -0.0385  0.00582
# 1     2018   126     2    38     3   917    17 -0.0469 -0.0385  0.00582
# 2     2018   126     2    38     5   453    20 -0.0469 -0.0385  0.00582
# 3     2018   126     2    38     6   477    22 -0.0469 -0.0385  0.00582
# 4     2018   126     2    38     6   989    23 -0.0469 -0.0385  0.00582
# ...    ...   ...   ...   ...   ...   ...   ...     ...     ...      ...
# 9994  2018   128     1    54    28   631    23 -0.0469 -0.0385  0.00577
# 9995  2018   128     1    54    30   167    26 -0.0469 -0.0385  0.00577
# 9996  2018   128     1    54    31   703    29 -0.0469 -0.0385  0.00577
# 9997  2018   128     1    54    35   287     4 -0.0469 -0.0385  0.00577
# 9998  2018   128     1    54    40   407    14 -0.0469 -0.0385  0.00577
#
#         col10   col11   col12    col13
# 0     0.01131 -0.0981 -0.0687  0.00661
# ...

# %% [markdown]
# # Mean, Median and Mode

# %%
df.mean()
# Out:
# date     2018.000000
# col1      126.598860
# col2       10.983998
# col3       29.113711
# col4       29.374237
# col5      501.154015
# col6       19.364836
# col7       -0.049502
# col8       -0.041822
# col9        0.005636
# col10       0.011097
# col11      -0.061196
# col12      -0.075725
# col13       0.006561
# dtype: float64

# %%
df.median()
# Out:
# date     2018.00000
# col1      127.00000
# col2       12.00000
# col3       29.00000
# col4       29.00000
# col5      504.00000
# col6       22.00000
# col7       -0.04690
# col8       -0.03850
# col9        0.00567
# col10       0.01111
# col11      -0.09810
# col12      -0.06870
# col13       0.00661
# dtype: float64

# %%
df.round(3).mode()
# Out:
#    date  col1  col2  col3  col4  col5  col6   col7   col8   col9  col10  \
# 0  2018   127    18    15     2   226    14 -0.047 -0.038  0.006  0.011
#
#    col11  col12  col13
# 0 -0.098 -0.069  0.007

# %% [markdown]
# # Visualize outliers

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set(rc={"figure.figsize":(6, 5)})
df_temp=df.copy()
sns.distplot(df['col7'])
# Out:
# <AxesSubplot:xlabel='col7', ylabel='Density'>

# %%
sns.distplot(df['col10'])
# Out:
# <AxesSubplot:xlabel='col10', ylabel='Density'>

# %%
sns.distplot(df['col1'])
# Out:
# <AxesSubplot:xlabel='col1', ylabel='Density'>

# %%
sns.distplot(df['col2'])
# Out:
# <AxesSubplot:xlabel='col2', ylabel='Density'>

# %% [markdown]
# # Find outliers

# %%
df.describe()
# Out:
#          date        col1         col2         col3         col4         col5  \
# count  9999.0  9999.00000  9999.000000  9999.000000  9999.000000  9999.000000
# mean   2018.0   126.59886    10.983998    29.113711    29.374237   501.154015
# std       0.0     0.58075     6.649014    17.093835    17.354227   288.660251
# min    2018.0   126.00000     0.000000     0.000000     0.000000     0.000000
# 25%    2018.0   126.00000     5.000000    14.000000    14.000000   251.000000
# 50%    2018.0   127.00000    12.000000    29.000000    29.000000   504.000000
# 75%    2018.0   127.00000    17.000000    44.000000    44.000000   750.000000
# max    2018.0   128.00000    23.000000    59.000000    59.000000   999.000000
#
#               col6         col7         col8         col9        col10  \
# count  9999.000000  9999.000000  9999.000000  9999.000000  9999.000000
# mean     19.364836    -0.049502    -0.041822     0.005636     0.011097
# ...

# %%
#finding min and max threshold
min_th, max_th = df.col2.quantile([0.05,0.95])
min_th, max_th
# Out:
# (1.0, 22.0)

# %%
#identifying the outliers
df[df['col2']>max_th]
# Out:
#       date  col1  col2  col3  col4  col5  col6    col7    col8     col9  \
# 4216  2018   126    23     2    23   550     4 -0.0469 -0.0385  0.00547
# 4217  2018   126    23     2    28   670    14 -0.0469 -0.0385  0.00547
# 4218  2018   126    23     2    30   206    17 -0.0469 -0.0385  0.00547
# 4219  2018   126    23     2    31   742    20 -0.0469 -0.0385  0.00547
# 4220  2018   126    23     2    32   766    22 -0.0469 -0.0385  0.00547
# ...    ...   ...   ...   ...   ...   ...   ...     ...     ...      ...
# 9509  2018   127    23    57    51    85    20 -0.0469 -0.0385  0.00577
# 9510  2018   127    23    57    52   109    22 -0.0469 -0.0385  0.00577
# 9511  2018   127    23    57    52   621    23 -0.0469 -0.0385  0.00562
# 9512  2018   127    23    57    54   157    26 -0.0469 -0.0385  0.00562
# 9513  2018   127    23    57    55   693    29 -0.0469 -0.0385  0.00562
#
#         col10   col11   col12    col13
# 4216  0.01096 -0.0981 -0.0687  0.00695
# ...

# %%
df[df['col2']<min_th]
# Out:
#       date  col1  col2  col3  col4  col5  col6    col7    col8     col9  \
# 4496  2018   127     0     3    33   587     4 -0.0469 -0.0385  0.00582
# 4497  2018   127     0     3    38   707    14 -0.0469 -0.0385  0.00582
# 4498  2018   127     0     3    40   243    17 -0.0469 -0.0385  0.00582
# 4499  2018   127     0     3    41   779    20 -0.0469 -0.0385  0.00582
# 4500  2018   127     0     3    42   803    22 -0.0469 -0.0385  0.00582
# ...    ...   ...   ...   ...   ...   ...   ...     ...     ...      ...
# 9832  2018   128     0    57    39   203    20 -0.0469 -0.0385  0.00526
# 9833  2018   128     0    57    40   227    22 -0.0469 -0.0385  0.00526
# 9834  2018   128     0    57    40   739    23 -0.0469 -0.0385  0.00547
# 9835  2018   128     0    57    42   275    26 -0.0469 -0.0385  0.00547
# 9836  2018   128     0    57    43   811    29 -0.0469 -0.0385  0.00547
#
#         col10   col11   col12    col13
# 4496  0.01131 -0.0981 -0.0687  0.00656
# ...

# %% [markdown]
# # removing outliers

# %%
df2=df[(df.col2<max_th) & (df.col2>min_th)]
df2.head()
# Out:
#    date  col1  col2  col3  col4  col5  col6    col7    col8     col9    col10  \
# 0  2018   126     2    38     2   381    14 -0.0469 -0.0385  0.00582  0.01131
# 1  2018   126     2    38     3   917    17 -0.0469 -0.0385  0.00582  0.01131
# 2  2018   126     2    38     5   453    20 -0.0469 -0.0385  0.00582  0.01131
# 3  2018   126     2    38     6   477    22 -0.0469 -0.0385  0.00582  0.01131
# 4  2018   126     2    38     6   989    23 -0.0469 -0.0385  0.00582  0.01131
#
#     col11   col12    col13
# 0 -0.0981 -0.0687  0.00661
# 1 -0.0981 -0.0687  0.00661
# 2 -0.0981 -0.0687  0.00661
# 3 -0.0981 -0.0687  0.00661
# 4 -0.0981 -0.0687  0.00661

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.rcParams['figure.figsize'] = [50,50]

# %% [markdown]
# # MinMax Scaling

# %%
# scale within range
min_max_scaler = preprocessing.MinMaxScaler()
df_minmax = min_max_scaler.fit_transform(df)

df_minmax = pd.DataFrame(df_minmax)

for i in range(19):
  m = np.mean(df_minmax[i])
  columns = np.where((df_minmax[i] >= m - (0.8 * m)) & (df_minmax[i] <= m + (0.8 * m)), 'm', 'k')
  plt.subplot(4,5,i + 1)
  plt.scatter(df_minmax.index,df_minmax[i], c = columns)
plt.show()

# %% [markdown]
# # Z-Score OR Standard Score

# %%
# represents num of sd away from mean
z_scaler = preprocessing.StandardScaler()
df_z = z_scaler.fit_transform(df)

df_z = pd.DataFrame(df_z)

for i in range(18):
  m = np.mean(df_z[i])
  cols = np.where((df_z[i] >= -0.8) & (df_z[i] <= 0.8), 'm', 'k')
  plt.subplot(4,5,i + 1)
  plt.scatter(df_z.index,newDf[i], c = cols)
plt.show()
