# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_fwf('./df/18.txt')
df.sample(5)
# Out:
#       2018  135  15  42  42.1  458  20  -0.04690  -0.03850  0.00536  ...  \
# 9365  2018  137   7  55     1   89  23   -0.0469   -0.0385  0.00567  ...
# 5376  2018  136  15   6    31  551  17   -0.0469   -0.0385  0.00567  ...
# 5545  2018  136  15  28    15  623   4   -0.0469   -0.0385  0.00572  ...
# 2314  2018  136   2  37    34  586  26   -0.0469   -0.0385  0.00582  ...
# 7779  2018  137   0  56    40  657  23   -0.0469   -0.0385  0.00582  ...
#
#       51.00.1  SYNC  ON  ON.1  ON.2  SYNC.1  NOT_USBL  ENA  LOW ON.3
# 9365     51.0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 5376     51.0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 5545     51.0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 2314     51.0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
# 7779     51.0  SYNC  ON    ON    ON    SYNC  NOT_USBL  ENA  LOW   ON
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#          2018          135           15           42         42.1  \
# count  9999.0  9999.000000  9999.000000  9999.000000  9999.000000
# mean   2018.0   136.053805    11.184518    30.179818    29.547255
# std       0.0     0.638425     6.911730    16.971602    17.325466
# min    2018.0   135.000000     0.000000     0.000000     0.000000
# 25%    2018.0   136.000000     5.000000    16.000000    15.000000
# 50%    2018.0   136.000000    12.000000    31.000000    29.000000
# 75%    2018.0   136.000000    17.000000    45.000000    45.000000
# max    2018.0   137.000000    23.000000    59.000000    59.000000
#
#                458           20     -0.04690     -0.03850      0.00536  \
# count  9999.000000  9999.000000  9999.000000  9999.000000  9999.000000
# mean    498.160316    19.382638    -0.052149    -0.037133     0.005628
# std     288.901919     7.305496     0.101520     0.163986     0.000739
# min       0.000000     4.000000    -0.959700    -1.923300    -0.000400
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   2018      9999 non-null   int64
#  1   135       9999 non-null   int64
#  2   15        9999 non-null   int64
#  3   42        9999 non-null   int64
#  4   42.1      9999 non-null   int64
#  5   458       9999 non-null   int64
#  6   20        9999 non-null   int64
#  7   -0.04690  9999 non-null   float64
#  8   -0.03850  9999 non-null   float64
#  9   0.00536   9999 non-null   float64
#  10  0.01121   9999 non-null   float64
#  11  -0.09810  9999 non-null   float64
#  12  -0.06870  9999 non-null   float64
#  13  0.00622   9999 non-null   float64
#  14  0.00759   9999 non-null   float64
#  15  37.00     9999 non-null   float64
#  16  51.00     9999 non-null   float64
#  17  37.00.1   9999 non-null   float64
#  18  51.00.1   9999 non-null   float64
#  19  SYNC      9999 non-null   object
# ...

# %%
# import missingno as msno
# null_count_plot = msno.bar(df)

# # as per initial analysis we did not find any null value, except for column_29 where there is no df entry

# %%
distribution_plot = df.hist(figsize = (20,20))

# %%
# Out:
#       Column1  Column2  Column3  Column4  Column5  Column6  Column7  Column8  \
# 7318     2018      107        1       52       58      145       22  -0.0469
# 3591     2018      106       11        3       14      629       14  -0.0469
# 8922     2018      107        8       26       46       75       26  -0.0469
# 3899     2018      106       12        7       28      988       22  -0.0469
# 1725     2018      106        3       26       51      663        4  -0.0469
#
#       Column9  Column10  ...  Column19  Column20  Column21  Column22  \
# 7318  -0.0385   0.00536  ...        52      SYNC        ON        ON
# 3591  -0.0385   0.00577  ...        51      SYNC        ON        ON
# 8922  -0.0385   0.00577  ...        51      SYNC        ON        ON
# 3899  -0.0385   0.00536  ...        52      SYNC        ON        ON
# 1725  -0.0385   0.00577  ...        51      SYNC        ON        ON
#
#       Column23  Column24  Column25  Column26  Column27 Column28
# ...

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)
#     Draw a box and whisker plot.
#
#     The box extends from the first quartile (Q1) to the third
#     quartile (Q3) of the data, with a line at the median.  The
#     whiskers extend from the box by 1.5x the inter-quartile range
#     (IQR).  Flier points are those past the end of the whiskers.
#     See https://en.wikipedia.org/wiki/Box_plot for reference.
#
#     .. code-block:: none
#
#               Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                            |-----:-----|
# ...

# %%
# Adding COlumns
df.columns = ['column' + str(n) for n in range(1,29)]
df
df.drop(['column1'] + ['column' + str(n) for n in range(20,29)], axis=1, inplace = True)
df.head()
# Out:
#    column2  column3  column4  column5  column6  column7  column8  column9  \
# 0      135       15       42       43      482       22  -0.0469  -0.0385
# 1      135       15       42       43      994       23  -0.0469  -0.0385
# 2      135       15       42       45      530       26  -0.0469  -0.0385
# 3      135       15       42       47       66       29  -0.0469  -0.0385
# 4      135       15       46       56      412        4  -0.0469  -0.0385
#
#    column10  column11  column12  column13  column14  column15  column16  \
# 0   0.00536   0.01121   -0.0981   -0.0687   0.00622   0.00759      37.0
# 1   0.00562   0.01126   -0.0981   -0.0687   0.00636   0.00784      37.0
# 2   0.00562   0.01126   -0.0981   -0.0687   0.00636   0.00784      37.0
# 3   0.00562   0.01126   -0.0981   -0.0687   0.00636   0.00784      37.0
# 4   0.00562   0.01126   -0.0981   -0.0687   0.00636   0.00784      37.0
#
#    column17  column18  column19
# 0      51.0      37.0      51.0
# ...

# %%
max=df['column6'].quantile(0.95)
df[df['column6']>max]

max

min=df['column6'].quantile(0.05)
df[df['column6']<min]
min
# Out:
# 47.0

# %%
plt.rcParams['figure.figsize'] = [50, 50]

# %%
# Plot max absolute

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
newDf = min_max_scaler.fit_transform(df)

newDf = pd.DataFrame(newDf)

for i in range(18):
  m = np.mean(newDf[i])
  cols = np.where((newDf[i] >= m - (0.8 * m)) & (newDf[i] <= m + (0.8 * m)), 'b', 'r')
  plt.subplot(4,5,i + 1)
  plt.scatter(newDf.index,newDf[i], c = cols)
plt.show()
